# %%
import pandas as pd
import numpy as np

# %%
import requests

# %%
url = "https://www.checkpoint.com/support-services/support-life-cycle-policy/"

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36",
    "Referer": "https://www.checkpoint.com/support-services/support-life-cycle-policy/",
    "Accept-Language": "en-US,en;q=0.9",
    "Accept-Encoding": "gzip, deflate, br",
    "Connection": "keep-alive",
    "Upgrade-Insecure-Requests": "1",
}

# %%
requests.get(url)
# Out:
# <Response [200]>

# %%
webpage = requests.get(url, headers=headers).text

# %%
webpage
# Out:
# '<!DOCTYPE html>\n<html lang="en-US">\n<head>\n  <meta http-equiv="X-UA-Compatible" content="IE=11,IE=10,IE=9,IE=8">\n  <meta charset="UTF-8">\n  <meta name="viewport" content="width=device-width, initial-scale=1.0">\n  <link rel="preconnect" href="//checkpoint.com">\n  <title>Support Life Cycle Policy - Check Point Software</title>\n        <meta class=\'swiftype\' name=\'popularity\' data-type=\'integer\' content=\'4\' />\n      <link rel="profile" href="https://gmpg.org/xfn/11">\n      <link rel="apple-touch-icon" sizes="180x180" href="//www.checkpoint.com/wp-content/themes/checkpoint-theme-v2/images/fav/apple-touch-icon.png">\n    <link rel="icon" type="image/png" sizes="32x32" href="//www.checkpoint.com/wp-content/themes/checkpoint-theme-v2/images/fav/favicon-32x32.png">\n    <link rel="icon" type="image/png" sizes="16x16" href="//www.checkpoint.com/wp-content/themes/checkpoint-theme-v2/images/fav/favicon-16x16.png">\n    <link rel="manifest" href="//www.checkpoint.com/wp-conten
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(webpage,'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
# <meta content="IE=11,IE=10,IE=9,IE=8" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="//checkpoint.com" rel="preconnect"/>
# <title>Support Life Cycle Policy - Check Point Software</title>
# <meta class="swiftype" content="4" data-type="integer" name="popularity"/>
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <link href="//www.checkpoint.com/wp-content/themes/checkpoint-theme-v2/images/fav/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="//www.checkpoint.com/wp-content/themes/checkpoint-theme-v2/images/fav/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="//www.checkpoint.com/wp-content/themes/checkpoint-theme-v2/images/fav/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# ...

# %%
soup.find_all('tr')
# Out:
# [<tr>
#  <th style="background-color: #545454; font-size: 16px;">Product</th>
#  <th style="background-color: #545454; font-size: 16px;">End of Sale</th>
#  <th style="background-color: #545454; font-size: 16px;">End of Support</th>
#  <th style="background-color: #545454; font-size: 16px;">Recommended Successor Product</th>
#  <th style="background-color: #545454; font-size: 16px;">Notification</th>
#  </tr>,
#  <tr>
#  <td>910 Appliance</td>
#  <td>Aug 2021</td>
#  <td>Aug 2026</td>
#  <td>1600</td>
#  <td>February 2021</td>
#  </tr>,
#  <tr>
#  <td>1200R Appliance</td>
#  <td>Dec 2020</td>
#  <td>Dec 2025</td>
#  <td>1570R</td>
#  <td>July 2020</td>
#  </tr>,
#  <tr>
#  <td>730 Appliance</td>
#  <td>May 2020</td>
#  <td>Oct 2024</td>
#  <td>1535</td>
#  <td>October 2019</td>
#  </tr>,
#  <tr>
#  <td>750 Appliance</td>
#  <td>May 2020</td>
#  <td>Oct 2024</td>
#  <td>1550</td>
#  <td>October 2019</td>
#  </tr>,
#  <tr>
#  <td>770 Appliance</td>
#  <td>May 2020</td>
# ...

# %%
soup.find_all('td')[1].get_text(strip=True)
# Out:
# 'Aug 2021'

# %%
table = soup.find_all('td')[0]  # Get the 3rd table (index starts from 0)

# %%
soup.find_all('tr')[0].get_text()
# Out:
# '\nProduct\nEnd of Sale\nEnd of Support\nRecommended Successor Product\nNotification\n'

# %%
soup.find_all('tr')[0].get_text().strip().split('\n')
# Out:
# ['Product',
#  'End of Sale',
#  'End of Support',
#  'Recommended Successor Product',
#  'Notification']

# %%
all_data = soup.find_all('tr')

# %%
[i.get_text().strip().split('\n') for i in all_data]
# Out:
# [['Product',
#   'End of Sale',
#   'End of Support',
#   'Recommended Successor Product',
#   'Notification'],
#  ['910 Appliance', 'Aug 2021', 'Aug 2026', '1600', 'February 2021'],
#  ['1200R Appliance', 'Dec 2020', 'Dec 2025', '1570R', 'July 2020'],
#  ['730 Appliance', 'May 2020', 'Oct 2024', '1535', 'October 2019'],
#  ['750 Appliance', 'May 2020', 'Oct 2024', '1550', 'October 2019'],
#  ['770 Appliance', 'May 2020', 'Oct 2024', '1570', 'October 2019'],
#  ['790 Appliance', 'May 2020', 'Oct 2024', '1590', 'October 2019'],
#  ['1430 Appliance', 'May 2020', 'Oct 2024', '1535', 'October 2019'],
#  ['1450 Appliance', 'May 2020', 'Oct 2024', '1550', 'October 2019'],
#  ['1470 Appliance', 'May 2020', 'Oct 2024', '1570', 'October 2019'],
#  ['1490 Appliance', 'May 2020', 'Oct 2024', '1590', 'October 2019'],
#  ['3100 Appliance', 'Dec 2020', 'Dec 2025', '3600', 'July 2020'],
#  ['3200 Appliance', 'Dec 2020', 'Dec 2025', '3800', 'July 2020'],
# ...

# %%
my_data = [i.get_text().strip().split('\n') for i in all_data]

# %%
my_data[33]
# Out:
# ['Major Version', 'General Availability', 'Affected Versions', 'Support Until']

# %%
my_data[0][0]
# Out:
# 'Product'

# %%
for i in my_data:
    print(i)
# Out:
# ['Product', 'End of Sale', 'End of Support', 'Recommended Successor Product', 'Notification']
# ['910 Appliance', 'Aug 2021', 'Aug 2026', '1600', 'February 2021']
# ['1200R Appliance', 'Dec 2020', 'Dec 2025', '1570R', 'July 2020']
# ['730 Appliance', 'May 2020', 'Oct 2024', '1535', 'October 2019']
# ['750 Appliance', 'May 2020', 'Oct 2024', '1550', 'October 2019']
# ['770 Appliance', 'May 2020', 'Oct 2024', '1570', 'October 2019']
# ['790 Appliance', 'May 2020', 'Oct 2024', '1590', 'October 2019']
# ['1430 Appliance', 'May 2020', 'Oct 2024', '1535', 'October 2019']
# ['1450 Appliance', 'May 2020', 'Oct 2024', '1550', 'October 2019']
# ['1470 Appliance', 'May 2020', 'Oct 2024', '1570', 'October 2019']
# ['1490 Appliance', 'May 2020', 'Oct 2024', '1590', 'October 2019']
# ['3100 Appliance', 'Dec 2020', 'Dec 2025', '3600', 'July 2020']
# ['3200 Appliance', 'Dec 2020', 'Dec 2025', '3800', 'July 2020']
# ['5100 Appliance', 'Dec 2020', 'Dec 2025', '9100', 'February 2024']
# ...

# %%
headings = []

# %%
soup.find_all('table',class_='table table-bordered table-striped')
# Out:
# [<table class="table table-bordered table-striped">
#  <thead>
#  <tr>
#  <th style="background-color: #545454; font-size: 16px;">Product</th>
#  <th style="background-color: #545454; font-size: 16px;">End of Sale</th>
#  <th style="background-color: #545454; font-size: 16px;">End of Support</th>
#  <th style="background-color: #545454; font-size: 16px;">Recommended Successor Product</th>
#  <th style="background-color: #545454; font-size: 16px;">Notification</th>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>910 Appliance</td>
#  <td>Aug 2021</td>
#  <td>Aug 2026</td>
#  <td>1600</td>
#  <td>February 2021</td>
#  </tr>
#  <tr>
#  <td>1200R Appliance</td>
#  <td>Dec 2020</td>
#  <td>Dec 2025</td>
#  <td>1570R</td>
#  <td>July 2020</td>
#  </tr>
#  <tr>
#  <td>730 Appliance</td>
#  <td>May 2020</td>
#  <td>Oct 2024</td>
#  <td>1535</td>
#  <td>October 2019</td>
#  </tr>
#  <tr>
#  <td>750 Appliance</td>
#  <td>May 2020</td>
#  <td>Oct 2024</td>
#  <td>1550</td>
# ...

# %%
soup.find_all('table',class_='table table-bordered table-striped')[0]
# Out:
# <table class="table table-bordered table-striped">
# <thead>
# <tr>
# <th style="background-color: #545454; font-size: 16px;">Product</th>
# <th style="background-color: #545454; font-size: 16px;">End of Sale</th>
# <th style="background-color: #545454; font-size: 16px;">End of Support</th>
# <th style="background-color: #545454; font-size: 16px;">Recommended Successor Product</th>
# <th style="background-color: #545454; font-size: 16px;">Notification</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>910 Appliance</td>
# <td>Aug 2021</td>
# <td>Aug 2026</td>
# <td>1600</td>
# <td>February 2021</td>
# </tr>
# <tr>
# <td>1200R Appliance</td>
# <td>Dec 2020</td>
# <td>Dec 2025</td>
# <td>1570R</td>
# <td>July 2020</td>
# </tr>
# <tr>
# <td>730 Appliance</td>
# <td>May 2020</td>
# <td>Oct 2024</td>
# <td>1535</td>
# <td>October 2019</td>
# </tr>
# <tr>
# <td>750 Appliance</td>
# <td>May 2020</td>
# <td>Oct 2024</td>
# <td>1550</td>
# <td>October 2019</td>
# </tr>
# <tr>
# ...

# %%
soup.find_all('table',class_='table table-bordered table-striped')[1].get_text().strip().split("\n")
# Out:
# ['Major Version',
#  'General Availability',
#  'Affected Versions',
#  'Support Until',
#  '',
#  '',
#  '',
#  '',
#  'Check Point R82',
#  'October 2024',
#  'R82',
#  'October 2028',
#  '',
#  '',
#  'Check Point R81.20',
#  'November 2022',
#  'R81.20',
#  'November 2026',
#  '',
#  '',
#  'Check Point R81.10',
#  'July 2021',
#  'R81.10',
#  'March 2026',
#  '',
#  '',
#  'Check Point R81',
#  'October 2020',
#  'R81',
#  'October 2024',
#  '',
#  '',
#  'Check Point R80.40',
#  'January 2020',
#  'R80.40',
#  'April 2024',
#  '',
#  '',
#  'Check Point R80.20',
#  'September 2018',
#  'R80.20, R80.30***',
#  'September 2022',
#  '',
#  '',
#  'Check Point R80*',
#  'May 2017',
#  'R80, R80.10',
#  'January 2022',
#  '',
#  '',
#  'Check Point R77.30',
#  'May 2015',
#  'R77.30',
#  'September 2019',
#  '',
#  '',
#  'NGSE',
#  'April 2014',
#  'NGSE',
#  'April 2018',
#  '',
#  '',
#  'Check Point R77',
#  'August 2013',
#  'R77, R77.10, R77.20',
#  'August 2017',
#  '',
# ...

# %%
soup.find_all('table',class_='table table-bordered table-striped')[0]
# Out:
# <table class="table table-bordered table-striped">
# <thead>
# <tr>
# <th style="background-color: #545454; font-size: 16px;">Product</th>
# <th style="background-color: #545454; font-size: 16px;">End of Sale</th>
# <th style="background-color: #545454; font-size: 16px;">End of Support</th>
# <th style="background-color: #545454; font-size: 16px;">Recommended Successor Product</th>
# <th style="background-color: #545454; font-size: 16px;">Notification</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>910 Appliance</td>
# <td>Aug 2021</td>
# <td>Aug 2026</td>
# <td>1600</td>
# <td>February 2021</td>
# </tr>
# <tr>
# <td>1200R Appliance</td>
# <td>Dec 2020</td>
# <td>Dec 2025</td>
# <td>1570R</td>
# <td>July 2020</td>
# </tr>
# <tr>
# <td>730 Appliance</td>
# <td>May 2020</td>
# <td>Oct 2024</td>
# <td>1535</td>
# <td>October 2019</td>
# </tr>
# <tr>
# <td>750 Appliance</td>
# <td>May 2020</td>
# <td>Oct 2024</td>
# <td>1550</td>
# <td>October 2019</td>
# </tr>
# <tr>
# ...

# %%
aaa = soup.find_all('table',class_='table table-bordered table-striped')[0]

# %%
list(aaa)
# Out:
# ['\n',
#  <thead>
#  <tr>
#  <th style="background-color: #545454; font-size: 16px;">Product</th>
#  <th style="background-color: #545454; font-size: 16px;">End of Sale</th>
#  <th style="background-color: #545454; font-size: 16px;">End of Support</th>
#  <th style="background-color: #545454; font-size: 16px;">Recommended Successor Product</th>
#  <th style="background-color: #545454; font-size: 16px;">Notification</th>
#  </tr>
#  </thead>,
#  '\n',
#  <tbody>
#  <tr>
#  <td>910 Appliance</td>
#  <td>Aug 2021</td>
#  <td>Aug 2026</td>
#  <td>1600</td>
#  <td>February 2021</td>
#  </tr>
#  <tr>
#  <td>1200R Appliance</td>
#  <td>Dec 2020</td>
#  <td>Dec 2025</td>
#  <td>1570R</td>
#  <td>July 2020</td>
#  </tr>
#  <tr>
#  <td>730 Appliance</td>
#  <td>May 2020</td>
#  <td>Oct 2024</td>
#  <td>1535</td>
#  <td>October 2019</td>
#  </tr>
#  <tr>
#  <td>750 Appliance</td>
#  <td>May 2020</td>
#  <td>Oct 2024</td>
#  <td>1550</td>
#  <td>October 2019</td>
#  </tr>
#  <tr>
# ...
