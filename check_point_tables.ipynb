# %%
import pandas as pd

# %%
url = "https://www.checkpoint.com/support-services/support-life-cycle-policy/"

# %%
tables = pd.read_html(url)

# %%
len(tables)
# Out:
# 33

# %%
type(tables)
# Out:
# list

# %%
import pickle

# %%
with open ('tables.pkl','wb') as f:
    pickle.dump(tables,f)

# %%
tables[0]['Product']
# Out:
# 0         910 Appliance
# 1       1200R Appliance
# 2         730 Appliance
# 3         750 Appliance
# 4         770 Appliance
# 5         790 Appliance
# 6        1430 Appliance
# 7        1450 Appliance
# 8        1470 Appliance
# 9        1490 Appliance
# 10       3100 Appliance
# 11       3200 Appliance
# 12       5100 Appliance
# 13       5200 Appliance
# 14       5400 Appliance
# 15       5600 Appliance
# 16       5800 Appliance
# 17       5900 Appliance
# 18       6500 Appliance
# 19       6800 Appliance
# 20      15400 Appliance
# 21      15600 Appliance
# 22      16000 Appliance
# 23      23500 Appliance
# 24      23800 Appliance
# 25      23900 Appliance
# 26         Capsule Docs
# 27    Capsule Workspace
# 28               TE100X
# 29               TE250X
# 30              TE1000X
# 31              TE2000X
# Name: Product, dtype: object

# %%
tables[0].iloc[0]
# Out:
# Product                          910 Appliance
# End of Sale                           Aug 2021
# End of Support                        Aug 2026
# Recommended Successor Product             1600
# Notification                     February 2021
# Name: 0, dtype: object

# %%
print(tables[0].iloc[1])
# Out:
# Product                          1200R Appliance
# End of Sale                             Dec 2020
# End of Support                          Dec 2025
# Recommended Successor Product              1570R
# Notification                           July 2020
# Name: 1, dtype: object

# %%
for table in tables:
    print(table.columns[0])
# Out:
# Product
# Major Version
# Service
# Major Version
# Major Version
# Version
# Major Version
# Service
# Service
# Service
# Major Version
# Appliance Product/Model
# Appliance Product/Model
# Appliance Product/Model
# Appliance Product/Model
# Appliance Product/Model
# Appliance Product/Model
# Appliance Product/Model
# Appliance Product/Model
# Appliance Product/Model
# Appliance Product/Model
# Appliance Product/Model
# Appliance Product/Model
# Appliance Product/Model
# ('IPSO Operating System Support', 'Product/Model')
# Appliance Product/Model
# Appliance Product/Model
# Appliance Product/Model
# Appliance Product/Model
# Appliance Product/Model
# Appliance Product/Model
# Appliance Product/Model
# Appliance Product/Model

# %%
all_first_column_values = []
for table in tables:
    first_col = table.columns[0]
    all_first_column_values.append(table[first_col])

# %%
all_first_column_values
# Out:
# [0         910 Appliance
#  1       1200R Appliance
#  2         730 Appliance
#  3         750 Appliance
#  4         770 Appliance
#  5         790 Appliance
#  6        1430 Appliance
#  7        1450 Appliance
#  8        1470 Appliance
#  9        1490 Appliance
#  10       3100 Appliance
#  11       3200 Appliance
#  12       5100 Appliance
#  13       5200 Appliance
#  14       5400 Appliance
#  15       5600 Appliance
#  16       5800 Appliance
#  17       5900 Appliance
#  18       6500 Appliance
#  19       6800 Appliance
#  20      15400 Appliance
#  21      15600 Appliance
#  22      16000 Appliance
#  23      23500 Appliance
#  24      23800 Appliance
#  25      23900 Appliance
#  26         Capsule Docs
#  27    Capsule Workspace
#  28               TE100X
#  29               TE250X
#  30              TE1000X
#  31              TE2000X
#  Name: Product, dtype: object,
#  0          Check Point R82
#  1       Check Point R81.20
#  2       Check Point R81.10
# ...

# %%
all_first_columns = []
for table in tables:
    first_col = table.columns[0]
    all_first_column_values.extend(table[first_col])

# %%
all_first_column_values
# Out:
# [0         910 Appliance
#  1       1200R Appliance
#  2         730 Appliance
#  3         750 Appliance
#  4         770 Appliance
#  5         790 Appliance
#  6        1430 Appliance
#  7        1450 Appliance
#  8        1470 Appliance
#  9        1490 Appliance
#  10       3100 Appliance
#  11       3200 Appliance
#  12       5100 Appliance
#  13       5200 Appliance
#  14       5400 Appliance
#  15       5600 Appliance
#  16       5800 Appliance
#  17       5900 Appliance
#  18       6500 Appliance
#  19       6800 Appliance
#  20      15400 Appliance
#  21      15600 Appliance
#  22      16000 Appliance
#  23      23500 Appliance
#  24      23800 Appliance
#  25      23900 Appliance
#  26         Capsule Docs
#  27    Capsule Workspace
#  28               TE100X
#  29               TE250X
#  30              TE1000X
#  31              TE2000X
#  Name: Product, dtype: object,
#  0          Check Point R82
#  1       Check Point R81.20
#  2       Check Point R81.10
# ...

# %%
[p for p in all_first_column_values]
# Out:
# [0         910 Appliance
#  1       1200R Appliance
#  2         730 Appliance
#  3         750 Appliance
#  4         770 Appliance
#  5         790 Appliance
#  6        1430 Appliance
#  7        1450 Appliance
#  8        1470 Appliance
#  9        1490 Appliance
#  10       3100 Appliance
#  11       3200 Appliance
#  12       5100 Appliance
#  13       5200 Appliance
#  14       5400 Appliance
#  15       5600 Appliance
#  16       5800 Appliance
#  17       5900 Appliance
#  18       6500 Appliance
#  19       6800 Appliance
#  20      15400 Appliance
#  21      15600 Appliance
#  22      16000 Appliance
#  23      23500 Appliance
#  24      23800 Appliance
#  25      23900 Appliance
#  26         Capsule Docs
#  27    Capsule Workspace
#  28               TE100X
#  29               TE250X
#  30              TE1000X
#  31              TE2000X
#  Name: Product, dtype: object,
#  0          Check Point R82
#  1       Check Point R81.20
#  2       Check Point R81.10
# ...

# %%
for table in tables:
    print(table.iloc[:,0])
# Out:
# 0         910 Appliance
# 1       1200R Appliance
# 2         730 Appliance
# 3         750 Appliance
# 4         770 Appliance
# 5         790 Appliance
# 6        1430 Appliance
# 7        1450 Appliance
# 8        1470 Appliance
# 9        1490 Appliance
# 10       3100 Appliance
# 11       3200 Appliance
# 12       5100 Appliance
# 13       5200 Appliance
# 14       5400 Appliance
# 15       5600 Appliance
# 16       5800 Appliance
# 17       5900 Appliance
# 18       6500 Appliance
# 19       6800 Appliance
# 20      15400 Appliance
# 21      15600 Appliance
# 22      16000 Appliance
# 23      23500 Appliance
# 24      23800 Appliance
# 25      23900 Appliance
# 26         Capsule Docs
# 27    Capsule Workspace
# 28               TE100X
# 29               TE250X
# 30              TE1000X
# 31              TE2000X
# Name: Product, dtype: object
# 0          Check Point R82
# 1       Check Point R81.20
# 2       Check Point R81.10
# 3          Check Point R81
# ...

# %%
for table in tables:
        row = table[table.iloc[:, 0] == 'Check Point R76']
        if not row.empty:
            print (row)
# Out:
#       Major Version General Availability Affected Versions  Support Until
# 10  Check Point R76        February 2013               R76  February 2017

# %%
for table in tables:
    print(table.iloc[:,0] == 'Check Point R76')
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# Name: Product, dtype: bool
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11    False
# 12    False
# 13    False
# 14    False
# Name: Major Version, dtype: bool
# 0    False
# 1    False
# 2    False
# Name: Service, dtype: bool
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# Name: Major Version, dtype: bool
# 0    False
# 1    False
# 2    False
# 3    False
# ...

# %%
tables[1].iloc[:,0] == 'Check Point R76'
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11    False
# 12    False
# 13    False
# 14    False
# Name: Major Version, dtype: bool

# %%
tables[1][tables[1].iloc[:,0] == 'Check Point R76']
# Out:
#       Major Version General Availability Affected Versions  Support Until
# 10  Check Point R76        February 2013               R76  February 2017

# %%
for i in all_first_column_values:
    print(i)
# Out:
# 0         910 Appliance
# 1       1200R Appliance
# 2         730 Appliance
# 3         750 Appliance
# 4         770 Appliance
# 5         790 Appliance
# 6        1430 Appliance
# 7        1450 Appliance
# 8        1470 Appliance
# 9        1490 Appliance
# 10       3100 Appliance
# 11       3200 Appliance
# 12       5100 Appliance
# 13       5200 Appliance
# 14       5400 Appliance
# 15       5600 Appliance
# 16       5800 Appliance
# 17       5900 Appliance
# 18       6500 Appliance
# 19       6800 Appliance
# 20      15400 Appliance
# 21      15600 Appliance
# 22      16000 Appliance
# 23      23500 Appliance
# 24      23800 Appliance
# 25      23900 Appliance
# 26         Capsule Docs
# 27    Capsule Workspace
# 28               TE100X
# 29               TE250X
# 30              TE1000X
# 31              TE2000X
# Name: Product, dtype: object
# 0          Check Point R82
# 1       Check Point R81.20
# 2       Check Point R81.10
# 3          Check Point R81
# ...

# %%
len('Please note version marked with:  * – require an available custom version for supporting this appliance  ** – are supported with SMART-1 25B only')
# Out:
# 145

# %%
len('Early SMART-1 Appliances')
# Out:
# 24

# %%
lengths = [len(val) for val in all_first_column_values]
print(f"Min length: {min(lengths)}")
print(f"Max length: {max(lengths)}")
print(f"Average length: {sum(lengths) / len(lengths)}")
print(f"Length distribution (first 10): {lengths[:10]}")
# Out:
# Min length: 2
# Max length: 928
# Average length: 20.360416666666666
# Length distribution (first 10): [13, 15, 13, 13, 13, 13, 14, 14, 14, 14]
